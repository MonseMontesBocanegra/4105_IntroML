# %% [markdown]
# <a href="https://colab.research.google.com/github/MonseMontesBocanegra/4105_IntroML/blob/Assignments/Homework7_Monse_MontesBocanegra_801297280.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Problem 1: Part 1
import tensorflow as tf
from tensorflow.keras import layers, models, datasets
import time

(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()


x_train, x_test = x_train / 255.0, x_test / 255.0


y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

def build_cnn():
    model = models.Sequential([
        # First Convolutional Block
        layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
        layers.Conv2D(32, (3, 3), strides=2, activation='relu'),  # Strided Convolution

        # Second Convolutional Block
        layers.Conv2D(64, (3, 3), activation='relu'),
        layers.Conv2D(64, (3, 3), strides=2, activation='relu'),  # Strided Convolution

        # Third Convolutional Block
        layers.Conv2D(128, (3, 3), activation='relu'),
        layers.Conv2D(128, (3, 3), strides=2, activation='relu'),  # Strided Convolution

        # Fully Connected Layers
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dense(10, activation='softmax')  # 10 output classes
    ])
    return model


model = build_cnn()


model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])


start_time = time.time()

history = model.fit(
    x_train, y_train,
    epochs=200,
    batch_size=64,
    validation_data=(x_test, y_test),
    verbose=1
)

end_time = time.time()
training_time = end_time - start_time


test_loss, test_accuracy = model.evaluate(x_test, y_test)

print("\n=== Training Results ===")
print(f"Training time (in seconds): {training_time:.2f}")
print(f"Final Training Loss: {history.history['loss'][-1]:.4f}")
print(f"Final Validation Accuracy: {history.history['val_accuracy'][-1]:.4f}")
print(f"Test Accuracy after 200 epochs: {test_accuracy:.4f}")


model.save("cifar10_cnn_strided_model.h5")
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 85s 104ms/step - accuracy: 0.3080 - loss: 1.8636 - val_accuracy: 0.4939 - val_loss: 1.3792
# Epoch 2/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 81s 104ms/step - accuracy: 0.5234 - loss: 1.3142 - val_accuracy: 0.5816 - val_loss: 1.1976
# Epoch 3/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 81s 102ms/step - accuracy: 0.6088 - loss: 1.0985 - val_accuracy: 0.6297 - val_loss: 1.0598
# Epoch 4/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 77s 99ms/step - accuracy: 0.6662 - loss: 0.9406 - val_accuracy: 0.6521 - val_loss: 0.9872
# Epoch 5/200
# ...

# %%
#Problem 1: Part 2 (This one is better, show both results but these are better, Case for depth and pooling)

import tensorflow as tf
from tensorflow.keras import layers, models, datasets
import time


(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()


x_train, x_test = x_train / 255.0, x_test / 255.0


y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)


def build_deep_cnn():
    model = models.Sequential([
        # First Convolutional Block (3x3 kernel, max pooling)
        layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)),
        layers.MaxPooling2D((2, 2)),

        # Second Convolutional Block
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),

        # Third Convolutional Block
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),

        # Fourth Convolutional Block (new layer to increase depth)
        layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),

        # Fully Connected Layers
        layers.Flatten(),
        layers.Dense(256, activation='relu'),  # Deeper dense layer for richer feature maps
        layers.Dense(10, activation='softmax')  # 10 output classes
    ])
    return model


model = build_deep_cnn()


model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])


start_time = time.time()

history = model.fit(
    x_train, y_train,
    epochs=200,
    batch_size=64,
    validation_data=(x_test, y_test),
    verbose=1
)

end_time = time.time()
training_time = end_time - start_time


test_loss, test_accuracy = model.evaluate(x_test, y_test)

print("\n=== Training Results ===")
print(f"Training time (in seconds): {training_time:.2f}")
print(f"Final Training Loss: {history.history['loss'][-1]:.4f}")
print(f"Final Validation Accuracy: {history.history['val_accuracy'][-1]:.4f}")
print(f"Test Accuracy after 200 epochs: {test_accuracy:.4f}")

model.save("cifar10_deep_cnn_model.h5")
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 8s 0us/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.3644 - loss: 1.7067 - val_accuracy: 0.5933 - val_loss: 1.1049
# Epoch 2/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.6335 - loss: 1.0322 - val_accuracy: 0.6771 - val_loss: 0.9233
# Epoch 3/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.7313 - loss: 0.7633 - val_accuracy: 0.7035 - val_loss: 0.8555
# Epoch 4/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7805 - loss: 0.6292 - val_accuracy: 0.7022 - val_loss: 0.8650
# Epoch 5/200
# ...

# %%
#Problem 2
import tensorflow as tf
from tensorflow.keras import layers, models, datasets
import time


(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0


y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

def residual_block(x, filters, kernel_size=3, strides=1):
    """Defines a single residual block."""
    shortcut = x

    # First convolution
    x = layers.Conv2D(filters, kernel_size, strides=strides, padding="same", activation="relu")(x)
    x = layers.BatchNormalization()(x)

    # Second convolution
    x = layers.Conv2D(filters, kernel_size, strides=1, padding="same")(x)
    x = layers.BatchNormalization()(x)

    # Add the shortcut (skip connection)
    if strides != 1 or x.shape[-1] != shortcut.shape[-1]:
        # Match dimensions
        shortcut = layers.Conv2D(filters, kernel_size=1, strides=strides, padding="same")(shortcut)
        shortcut = layers.BatchNormalization()(shortcut)

    x = layers.Add()([x, shortcut])
    x = layers.ReLU()(x)

    return x

def build_resnet10():
    inputs = tf.keras.Input(shape=(32, 32, 3))


    x = layers.Conv2D(16, (3, 3), strides=1, padding="same", activation="relu")(inputs)
    x = layers.BatchNormalization()(x)

    # Residual Blocks (10 blocks total)
    x = residual_block(x, 16)
    x = residual_block(x, 16)
    x = residual_block(x, 32, strides=2)  # Downsampling
    x = residual_block(x, 32)
    x = residual_block(x, 64, strides=2)  # Downsampling
    x = residual_block(x, 64)
    x = residual_block(x, 128, strides=2)  # Downsampling
    x = residual_block(x, 128)
    x = residual_block(x, 128)
    x = residual_block(x, 128)

    x = layers.GlobalAveragePooling2D()(x)
    outputs = layers.Dense(10, activation="softmax")(x)

    return models.Model(inputs, outputs)

model = build_resnet10()


model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])


start_time = time.time()

history = model.fit(
    x_train, y_train,
    epochs=200,
    batch_size=64,
    validation_data=(x_test, y_test),
    verbose=1
)

end_time = time.time()
training_time = end_time - start_time


test_loss, test_accuracy = model.evaluate(x_test, y_test)


print("\n=== Training Results ===")
print(f"Training time (in seconds): {training_time:.2f}")
print(f"Final Training Loss: {history.history['loss'][-1]:.4f}")
print(f"Final Validation Accuracy: {history.history['val_accuracy'][-1]:.4f}")
print(f"Test Accuracy after 200 epochs: {test_accuracy:.4f}")


model.save("cifar10_resnet10_model.h5")
# Out:
# Epoch 1/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 51s 35ms/step - accuracy: 0.3973 - loss: 1.6800 - val_accuracy: 0.5351 - val_loss: 1.3964
# Epoch 2/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 16s 17ms/step - accuracy: 0.6474 - loss: 0.9888 - val_accuracy: 0.4887 - val_loss: 1.8141
# Epoch 3/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 21s 18ms/step - accuracy: 0.7381 - loss: 0.7422 - val_accuracy: 0.7097 - val_loss: 0.8407
# Epoch 4/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 20s 17ms/step - accuracy: 0.7928 - loss: 0.5901 - val_accuracy: 0.7387 - val_loss: 0.7798
# Epoch 5/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.8283 - loss: 0.4920 - val_accuracy: 0.7163 - val_loss: 0.9080
# Epoch 6/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.8576 - loss: 0.4035 - val_accuracy: 0.7382 - val_loss: 0.8377
# Epoch 7/200
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 21s 18ms/step - accuracy: 0.8861 - loss: 0.3272 - val_accuracy: 0.7756 - val_loss: 0.7036
# Epoch 8/200
# ...
